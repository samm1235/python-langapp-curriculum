# %% [markdown]
# # Analyse `data/words.txt` here!
#
# Before we get started, we need to clean our data. There are acutally some duplicated words in our file! Verify for yourself that there are indeed duplicated words.

# %%
with open("data/words.txt","r") as files:
    lines = files.readlines()
    
print(lines)
# Out:
# ['xenial\n', 'unable\n', 'image\n', 'garden\n', 'market\n', 'earth\n', 'values\n', 'hidden\n', 'engine\n', 'settle\n', 'yearly\n', 'reason\n', 'jordan\n', 'binary\n', 'insect\n', 'legend\n', 'market\n', 'jingle\n', 'carbon\n', 'kicker\n', 'fellow\n', 'nickel\n', 'zigzag\n', 'vector\n', 'yonder\n', 'random\n', 'inside\n', 'united\n', 'weight\n', 'family\n', 'indoor\n', 'matrix\n', 'narrow\n', 'lively\n', 'jersey\n', 'others\n', 'order\n', 'handle\n', 'jockey\n', 'kidney\n', 'safety\n', 'season\n', 'table\n', 'wheels\n', 'leader\n', 'habit\n', 'doctor\n', 'xenic\n', 'global\n', 'kingly\n', 'farmer\n', 'sample\n', 'patrol\n', 'koala\n', 'urgent\n', 'patent\n', 'flower\n', 'parlour\n', 'master\n', 'universe\n', 'zipper\n', 'zombie\n', 'yesterday\n', 'vapor\n', 'xenia\n', 'glass\n', 'manner\n', 'family\n', 'zephyr\n', 'uncle\n', 'device\n', 'person\n', 'magnet\n', 'zeroes\n', 'cactus\n', 'income\n', 'safety\n', 'walker\n', 'breath\n', 'vanish\n', 'zenith\n', 'quick\n', 'bright\n', 'mental\n', 'guitar\n', 'zealot\n', 'laptop\n', 'letter\n', 'theory\n', 'quartz\n', 'circle\n', 'nature\n', 'column\n', 'yield\n', 'kindly\n', 'health\n', 'tennis\n', 'teacher\n', 'parent\n', 'yammer\n', 'alarm\n', 'marine\n', 'effect\n', 'almost\n', 'height\n', 'object\n', 'knight\n', 'orbit\n', 'artist\n', 'autumn\n', 'xylyl\n', 'orange\n', 'harbor\n', 'planet\n', 'velvet\n', 'unique\n', 'unseen\n', 'washer\n', 'beyond\n', 'talent\n', 'desert\n', 'quota\n', 'degree\n', 'arrow\n', 'keyboard\n', 'palace\n', 'school\n', 'pencil\n', 'debate\n', 'knives\n', 'window\n', 'series\n', 'apple\n', 'timber\n', 'region\n', 'vendor\n', 'reader\n', 'vacant\n', 'custom\n', 'nephew\n', 'across\n', 'xenon\n', 'bounce\n', 'rabbit\n', 'levels\n', 'active\n', 'echo\n', 'eight\n', 'opener\n', 'ladder\n', 'hammer\n', 'zoomed\n', 'yawned\n', 'radius\n', 'bridge\n', 'memory\n', 'battle\n', 'second\n', 'famous\n', 'under\n', 'queen\n', 'jacket\n', 'island\n', 'yogurt\n', 'dragon\n', 'tenant\n', 'temple\n', 'xerox\n', 'golden\n', 'keeper\n', 'rather\n', 'jester\n', 'jargon\n', 'yellow\n', 'method\n', 'figure\n', 'update\n', 'ghost\n', 'quiet\n', 'network\n', 'queue\n', 'quake\n', 'gather\n', 'zoning\n', 'packet\n', 'weapon\n', 'victim\n', 'ocean\n', 'intent\n', 'radial\n', 'button\n', 'basket\n', 'journey\n', 'ticket\n', 'parity\n', 'infant\n', 'ground\n', 'fabric\n', 'history\n', 'wander\n', 'screen\n', 'native\n', 'either\n', 'nervous\n', 'eager\n', 'effort\n', 'target\n', 'quest\n', 'record\n', 'xenon\n', 'middle\n', 'nearly\n', 'lights\n', 'change\n', 'query\n', 'jaguar\n', 'xylem\n', 'journal\n', 'helmet\n', 'atlas\n', 'xenops\n', 'wanted\n', 'happen\n', 'dialog\n', 'vessel\n', 'xebec\n', 'xeric\n', 'realty\n', 'bubble\n', 'canvas\n', 'obtain\n', 'unless\n', 'index\n', 'gentle\n', 'sensor\n', 'office\n', 'coffee\n', 'danger\n', 'walnut\n', 'league\n', 'valley\n', 'castle\n', 'factor\n', 'field\n', 'dancer\n', 'weekly\n', 'energy\n', 'layout\n', 'zodiac\n', 'impact\n', 'nights\n', 'needle\n', 'dinner\n', 'quaint\n', 'camera\n', 'anchor\n', 'online\n', 'father\n', 'elbow\n', 'kettle\n', 'camera\n', 'giant\n', 'yeller\n', 'salary\n', 'yachts\n', 'packet']

# %% [markdown]
# Using code, find the duplicated words and remove the duplicates so that each word only appears once. Next, sort the words into alphabetical order using `sorted(list)` or `list.sort()` to improve organisation. Save your new word file as `words_cleaned.txt` in the same format. From now on, you should be using `words_cleaned.txt`.
#
# If your new file has 260 word (lines), you did it correctly!

# %%
unique = []

for word in lines:
    if word not in unique:
        word = word.strip()
        unique.append(word)

unique.sort()
print(unique)
# Out:
# ['across', 'active', 'alarm', 'almost', 'anchor', 'apple', 'arrow', 'artist', 'atlas', 'autumn', 'basket', 'battle', 'beyond', 'binary', 'bounce', 'breath', 'bridge', 'bright', 'bubble', 'button', 'cactus', 'camera', 'camera', 'canvas', 'carbon', 'castle', 'change', 'circle', 'coffee', 'column', 'custom', 'dancer', 'danger', 'debate', 'degree', 'desert', 'device', 'dialog', 'dinner', 'doctor', 'dragon', 'eager', 'earth', 'echo', 'effect', 'effort', 'eight', 'either', 'elbow', 'energy', 'engine', 'fabric', 'factor', 'family', 'family', 'famous', 'farmer', 'father', 'fellow', 'field', 'figure', 'flower', 'garden', 'gather', 'gentle', 'ghost', 'giant', 'glass', 'global', 'golden', 'ground', 'guitar', 'habit', 'hammer', 'handle', 'happen', 'harbor', 'health', 'height', 'helmet', 'hidden', 'history', 'image', 'impact', 'income', 'index', 'indoor', 'infant', 'insect', 'inside', 'intent', 'island', 'jacket', 'jaguar', 'jargon', 'jersey', 'jester', 'jingle', 'jockey', 'jordan', 'journal', 'journey', 'keeper', 'kettle', 'keyboard', 'kicker', 'kidney', 'kindly', 'kingly', 'knight', 'knives', 'koala', 'ladder', 'laptop', 'layout', 'leader', 'league', 'legend', 'letter', 'levels', 'lights', 'lively', 'magnet', 'manner', 'marine', 'market', 'market', 'master', 'matrix', 'memory', 'mental', 'method', 'middle', 'narrow', 'native', 'nature', 'nearly', 'needle', 'nephew', 'nervous', 'network', 'nickel', 'nights', 'object', 'obtain', 'ocean', 'office', 'online', 'opener', 'orange', 'orbit', 'order', 'others', 'packet', 'palace', 'parent', 'parity', 'parlour', 'patent', 'patrol', 'pencil', 'person', 'planet', 'quaint', 'quake', 'quartz', 'queen', 'query', 'quest', 'queue', 'quick', 'quiet', 'quota', 'rabbit', 'radial', 'radius', 'random', 'rather', 'reader', 'realty', 'reason', 'record', 'region', 'safety', 'safety', 'salary', 'sample', 'school', 'screen', 'season', 'second', 'sensor', 'series', 'settle', 'table', 'talent', 'target', 'teacher', 'temple', 'tenant', 'tennis', 'theory', 'ticket', 'timber', 'unable', 'uncle', 'under', 'unique', 'united', 'universe', 'unless', 'unseen', 'update', 'urgent', 'vacant', 'valley', 'values', 'vanish', 'vapor', 'vector', 'velvet', 'vendor', 'vessel', 'victim', 'walker', 'walnut', 'wander', 'wanted', 'washer', 'weapon', 'weekly', 'weight', 'wheels', 'window', 'xebec', 'xenia', 'xenial', 'xenic', 'xenon', 'xenon', 'xenops', 'xeric', 'xerox', 'xylem', 'xylyl', 'yachts', 'yammer', 'yawned', 'yearly', 'yeller', 'yellow', 'yesterday', 'yield', 'yogurt', 'yonder', 'zealot', 'zenith', 'zephyr', 'zeroes', 'zigzag', 'zipper', 'zodiac', 'zombie', 'zoning', 'zoomed']

# %% [markdown]
# ## Some ideas for data analysis:
# - Find the total number of words

# %%
print(len(lines))
# Out:
# 266

# %% [markdown]
# - Find all words that start with a specified letter

# %%
starting_with_s = []
for word in lines:
    if word[0] == 's':
        word = word.strip()
        starting_with_s.append(word)
print(starting_with_s)
# Out:
# ['settle', 'safety', 'season', 'sample', 'safety', 'school', 'series', 'second', 'screen', 'sensor', 'salary']

# %% [markdown]
# - Find the shortest, longest words and their lengths & find the mean, median, modal length of each word

# %%
for word in lines:
    count= len(word)
# Out:
# 7
# 7
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 6
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 8
# 7
# 9
# 7
# 7
# 10
# 6
# 6
# 6
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 8
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 6
# 9
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 5
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 8
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 7
# 7
# 8
# 6
# 7
# 7
# 6
# 7
# 6
# 7
# 7
# 7
# 7
# 6
# 7
# 6
# 8
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 7
# 7
# 6
# 7
# 7
# 7
# 6

# %% [markdown]
# - Strip all vowels from each word and write these “consonant-only” words into a new file -> `words_no_vowels.txt`

# %% [markdown]
# ## Feel free to play around with the data in any other way you want!
